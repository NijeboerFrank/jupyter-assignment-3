# %% [markdown]
# # An Analysis on a GreyMarket on the Dark Web
#     Loek van der Gugten 1975331
#     Reinier de Ridder   1701134
#     Frank Nijeboer      2011972

# %% [markdown]
# ## Motivation and Goals
# This document contains an analysis of items that are listed on a black market website. The black market website that has been analyzed is called ‘Grey Market’ according to the website ‘Darknet Markets Links’. On ‘Grey Market’ you can find a wide variety of items, ranging from drugs to accounts on online services, from software applications to bank accounts, etc. You can access this black market through the Tor browser. The link to ‘Grey Market’ only works in this browser.
#
# There are multiple goals for performing this analysis, the first being understanding how the black market works. The idea is that by going through items on a black market we can get an overview of what kind of items are listed and how much information about the item and/or seller is provided per item. The second goal is to form an opinion about the legality of the items we find. It is very likely that we will encounter items that are considered illegal in  the Netherlands. However not every items necessarily is illegal. Therefore for each item we analyse, we indicate whether we think it is legal and thus, should we be in contact with the police, whether the police should further investigate the item and/or seller.

# %% [markdown]
# ## Methodology
# To do the analysis we decided to go through 100 items on the ‘Grey Market’ website by doing 33% each. For each item we listed details about the item such as the price and the seller. The results we wrote down and then analyzed to draw a conclusion. More about the results can be found below.
#
# The first result consists of exactly 100 analyzations of items on the website ‘Grey Market’. All of the items we analyzed belonged to the category ‘Digital’. Three subcategories were explored: ‘Information’, ‘Fraud’ and ‘Software’. We chose around 33 items in each subcategory.
#
# Per item we listed the following properties:
# * Name
# * Type of item according to ‘Grey Market’
# * Quantity in which you buy it
# * Price per Quantity in United States Dollars
# * Account-name of the Seller,
# * Where it will be shipped from
# * Where it can be shipped to
# * Whether or not we think it is legal (Yes if we think it is legal, Yes? if we think it is legal but are not sure (depends), and No if we think it is illegal)
# * The subcategory the item belongs to
# * How many pieces of the item are still in stock according to the seller.
#
# All of this information can be found on the explore page or the page of the item on the website of the 'Gray Market'.
#
# After manually harvesting this data from our chosen 'Gray Market', we will start our analysis on this data. This will be done by making plots in Jupyter Notebook using pandas and matplotlib. We will plot this data to answer the following questions:

# %% [markdown]
# ## Data
# Below the data that we have gathered can be found in the df variable.

# %%
from read_csv import df, seller_df
df
# Out:
#                                                  Name       Item  Quantity  \
# 0                             Amazon Carding Tutorial      eBook         1
# 1                        12 Ways To Rob A ATM Machine      eBook         1
# 2                                  How to use socks 5      files         1
# 3      Hdvpass.com Porn Premium Account Plus Warranty   accounts         1
# 4           NORD VPN 6 Months Subscription + WARRANTY   accounts         1
# 5       SisLovesMe Porn Premium Account Plus Warranty   accounts         1
# 6   Centoxcento.net Porn Premium Account Plus Warr...   accounts         1
# 7              '+7K Awesome Deep Web Onion Links List      files         1
# 8           EAT BURGER KING FOR FREE - TESTED WORKING     pieces         1
# 9   Pornpros.com Porn 11 Sites Platinum Access Accoun   accounts         1
# 10            Brazzers Porn Account Lifetime Warranty   accounts         1
# 11  Alljapanesepass.com Porn Premium Account Plus ...   accounts         1
# 12           x-art.com Porn Account Warranty Included   accounts         1
# 13                   THE AMAZON UNLIMITED MONEY GUIDE      files         1
# 14  Atkpetites.com Porn Premium Account Plus Warranty   accounts         1
# 15                 Deezer Premium Account w/ Warranty   accounts         1
# 16                                    CC To BTC Guide   accounts         1
# 17  NAUGHTYAMERICA.COM| NaughtyAmerica Premium Por...     pieces         1
# 18  NordVPN Premium Account 6 Months Subs Warranty...   accounts         1
# 19        ipvanish.com vpn + ipvanish premium account     pieces         1
# 20         PornHub Premium Porn Account Plus Warranty   accounts         1
# 21               EAT SUBWAY FOR FREE - exploit method     pieces         1
# 22    Dadcrush.com Porn Premium Account Plus Warranty   accounts         1
# 23         Redtube Premium Porn Account Plus Warranty   accounts         1
# 24          TIDAL Premium No HIFI Account w/ Warranty   accounts         1
# 25  NETFLIX 4K UHD ACCOUNT+ HBO NOW + SHOWTIME + HULU     pieces         1
# 26        Spotify Premium Account (+1 Bonus) Warranty   accounts         1
# 27          How To Stop Drug Dogs From Smelling Drugs     eBooks         1
# 28             RubMaps Only USA Account Plus Warranty   accounts         1
# 29  helixstudios.net Porn Premium Account Plus War...   accounts         1
# ..                                                ...        ...       ...
# 70                     PizzaHut 150 - 399 Points | US   accounts         1
# 71  Carding Tutorial Package Complete Guide To Car...     pieces         1
# 72               CREATE unlimited FAKE FRENCH ID scan     pieces         1
# 73                   Clearscore UK Account 500+ score   accounts         1
# 74                                Driver License Scan     pieces         1
# 75                               ITALIAN BANK ACCOUNT   accounts         1
# 76      *MAILBOX|MASTERKEY* AUSTRALIAN* BONUS RUNNING      other         1
# 77                          How To Clone Credit Cards     pieces         1
# 78         How to turn your CC and CVV into FULLZ !!!     pieces         1
# 79                      2019 NEW Paypal Cashout Guide     pieces         1
# 80          -AUSTRALIAN- BURNER SIM CARD* READY TO GO      other         1
# 81     1000$ US Paypal Balance +1000$ PP Acc For Free   accounts         1
# 82             Cineworld Unlimited card Accounts - UK   accounts         1
# 83  |||AUSTRALIAN||| BUY BTCMARKETS VERIFIED ACCOU...   accounts         1
# 84      18 Tutorials Mostly Carding Also Other Guides     pieces         1
# 85  Change your MAC by one click - must have for s...     pieces         1
# 86  VPN software + step by step guide - stay safe !!!     pieces         1
# 87  Learn everything about Proxy and become Anonymous     pieces         1
# 88      Trojan Remover 6.9.4.2943 Final + Cracked-SND     pieces         1
# 89           Recuva Professional - Technician cracked     pieces         1
# 90       Megapack of documents and currency templates      files         1
# 91           Gobank account + VBA + 2019 Cashout 100%   accounts         1
# 92                                    CC-CVV Checker.     pieces         1
# 93  greendot Bank account + VBA + VCC + 2019 Casho...   accounts         1
# 94           50 EURO BILLS TEMPLATES PSD HIGH QUALITY      files         1
# 95         22K BANK BALANCE! AUSTRALIAN BANK ACCOUNT!   accounts         1
# 96                     SSN Template PSD PERFECT EDIT!      files         1
# 97  APPLE ACCOUNTS AND CREDIT CARD FULL DATA. (OFFER)   accounts         1
# 98      -AUSTRALIAN- BANK DROPS PRE-SET- READY TO USE   accounts         1
# 99                              order fake passports,  documents         1
#
#    $/Quantity           Seller Shipping from Shipping to Legal  \
# 0           5    topnotchdrugz     Worldwide   Worldwide  Yes?
# 1           3    topnotchdrugz     Worldwide   Worldwide  Yes?
# 2           1         Hackyboy     Worldwide   Worldwide  Yes?
# 3           3  enjoymyaccounts     Worldwide   Worldwide    No
# 4         3.2       pornseller     Worldwide   Worldwide    No
# 5           5  enjoymyaccounts     Worldwide   Worldwide    No
# 6           3  enjoymyaccounts     Worldwide   Worldwide    No
# 7           2         Hackyboy     Worldwide   Worldwide  Yes?
# 8        2.07            g3cko     Worldwide   Worldwide    No
# 9           9  enjoymyaccounts     Worldwide   Worldwide    No
# 10       2.99       pornseller     Worldwide   Worldwide    No
# 11          4  enjoymyaccounts     Worldwide   Worldwide    No
# 12          6       pornseller     Worldwide   Worldwide    No
# 13          3         Hackyboy     Worldwide   Worldwide  Yes?
# 14          4  enjoymyaccounts     Worldwide   Worldwide    No
# 15       1.25   accountsheaven     Worldwide   Worldwide    No
# 16          3    topnotchdrugz     Worldwide   Worldwide  Yes?
# 17       2.95       Raperholic     Worldwide   Worldwide    No
# 18        3.5  enjoymyaccounts     Worldwide   Worldwide    No
# 19       2.08       Raperholic     Worldwide   Worldwide    No
# 20          3  enjoymyaccounts     Worldwide   Worldwide    No
# 21       2.08            g3cko     Worldwide   Worldwide    No
# 22          6  enjoymyaccounts     Worldwide   Worldwide    No
# 23          3  enjoymyaccounts     Worldwide   Worldwide    No
# 24       1.25   accountsheaven     Worldwide   Worldwide    No
# 25        3.9       Raperholic     Worldwide   Worldwide    No
# 26        1.3       pornseller     Worldwide   Worldwide    No
# 27          3    topnotchdrugz     Worldwide   Worldwide  Yes?
# 28          5  enjoymyaccounts     Worldwide   Worldwide    No
# 29          6  enjoymyaccounts     Worldwide   Worldwide    No
# ..        ...              ...           ...         ...   ...
# 70       2.75           Tactic     Worldwide   Worldwide   Yes
# 71       4.90          TheShop     Worldwide   Worldwide   Yes
# 72      13.19           Tactic     Worldwide   Worldwide   Yes
# 73       6.21            Enjoy     Worldwide   Worldwide   Yes
# 74       5.00       Raperholic     Worldwide   Worldwide   Yes
# 75   2,747.50   AmmaccaBanane2     Worldwide   Worldwide    No
# 76      18.10      brikzone123     Australia   Australia   Yes
# 77       5.00    topnotchdrugz     Worldwide   Worldwide   Yes
# 78       3.12            g3cko     Worldwide   Worldwide   Yes
# 79       5.00         Hackyboy     Worldwide   Worldwide   Yes
# 80       9.70      brikzone123     Australia   Worldwide   Yes
# 81      32.00         DrWhit3      Worldwide   Worldwide    No
# 82       6.21            Enjoy     Worldwide   Worldwide    No
# 83      20.30      brikzone123     Worldwide   Worldwide    No
# 84      10.00    topnotchdrugz     Worldwide   Worldwide   Yes
# 85       1.98            g3cko     Worldwide   Worldwide   Yes
# 86       1.98            g3cko     Worldwide   Worldwide   Yes
# 87      41.60            g3cko     Worldwide   Worldwide   Yes
# 88       1.98            g3cko     Worldwide   Worldwide    No
# 89       1.98            g3cko     Worldwide   Worldwide    No
# 90       2.08            g3cko     Worldwide   Worldwide    No
# 91      20.00       Raperholic     Worldwide   Worldwide    No
# 92       9.94   fraudsterelite     Worldwide   Worldwide   Yes
# 93      25.00      victorviran     Worldwide   Worldwide    No
# 94      15.00         Hackyboy     Worldwide   Worldwide    No
# 95     199.00      brikzone123     Worldwide   Worldwide    No
# 96      32.97           Tactic     Worldwide   Worldwide    No
# 97       8.79      C4RD1NGC0D3     Worldwide   Worldwide    No
# 98      35.67      brikzone123     Worldwide   Worldwide    No
# 99        400    caregivers420     Worldwide   Worldwide    No
#
#               Category  In Stock
# 0    Information/eBook     498.0
# 1    Information/eBook      99.0
# 2   Information/Guides     999.0
# 3    Information/other     998.0
# 4    Information/other     999.0
# 5    Information/other     998.0
# 6    Information/other     999.0
# 7   Information/Guides     998.0
# 8   Information/Guides    9999.0
# 9    Information/other     998.0
# 10   Information/other     999.0
# 11   Information/other     998.0
# 12   Information/other     999.0
# 13  Information/Guides     993.0
# 14   Information/other     999.0
# 15   Information/other     999.0
# 16   Information/eBook     495.0
# 17   Information/other     999.0
# 18   Information/other     995.0
# 19   Information/other     999.0
# 20   Information/other     998.0
# 21  Information/Guides    9999.0
# 22   Information/other     999.0
# 23   Information/other     999.0
# 24   Information/other     999.0
# 25   Information/other     997.0
# 26   Information/other     998.0
# 27   Information/eBook      99.0
# 28   Information/other     999.0
# 29   Information/other     999.0
# ..                 ...       ...
# 70               Fraud       3.0
# 71               Fraud       9.0
# 72               Fraud       8.0
# 73               Fraud      42.0
# 74               Fraud     999.0
# 75               Fraud     999.0
# 76               Fraud      45.0
# 77               Fraud      94.0
# 78               Fraud    9998.0
# 79               Fraud     997.0
# 80               Fraud     143.0
# 81               Fraud       8.0
# 82               Fraud      91.0
# 83               Fraud      24.0
# 84               Fraud      97.0
# 85            Security    9999.0
# 86            Security    9999.0
# 87            Security   10000.0
# 88            Security   10000.0
# 89            Security   10000.0
# 90               Fraud    9982.0
# 91               Fraud     998.0
# 92               Fraud   10000.0
# 93               Fraud    1000.0
# 94               Fraud    1000.0
# 95               Fraud       1.0
# 96               Fraud      15.0
# 97               Fraud   10000.0
# 98               Fraud      30.0
# 99               Fraud    1000.0
#
# [100 rows x 10 columns]

# %%
seller_df
# Out:
#              Seller  Open Orders  Completed Orders  Disputes Won  \
# 0             g3cko           15               146             2
# 1            Tactic            3                85             1
# 2    fraudsterelite            0                12             1
# 3     topnotchdrugz           10                96             0
# 4        leaguemode            0                 0             0
# 5          Hackyboy           17                71             4
# 6       dumbakarahi            2                31             2
# 7           TheShop            2                18             0
# 8        Raperholic            5                33             0
# 9       victorviran            4                52             0
# 10   AmmaccaBanane2            0                 2             0
# 11      C4rD1NGC0D3            4                 1             0
# 12          DrWhit3           37               285             6
# 13       pornseller            0                12             0
# 14  enjoymyaccounts            1                72             0
# 15    accountheaven            0                 5             0
#
#     Disputes Lost  Rating
# 0               0     9.5
# 1               0    10.0
# 2               0    10.0
# 3               1     9.6
# 4               0     0.0
# 5               2     9.5
# 6               0     9.5
# 7               0     9.8
# 8               0     9.7
# 9               0     9.6
# 10              0    10.0
# 11              0    10.0
# 12              6     8.8
# 13              0    10.0
# 14              0     9.9
# 15              0    10.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Sellers
# We analysed the sellers of the selected products. Here we found that *g3cko* is the largest seller by 21 products. This is followed by *enjoymyaccounts* and *topnotchdrugz* with 13 and 8 products respectively. However, when looking at the amount of completed orders *g3ecko* is only the second largest seller, surpassed by *DrWhit3*. None of the sellers seem to be particularly malicious, having a high rating and low amount of *Disputes Lost*. *DrWhit3* has a relatively worse performance, with 2% of orders having a lost dispute. The only truely untrustworthy seller seems to be *leaguemode*, with no *Completed Orders* or a rating.

# %%
sellers_by_frequency = df["Seller"].value_counts()
sellers_by_frequency.sort_values().plot(kind='barh')
plt.title('Sellers by frequency')
plt.ylabel('Seller')
plt.xlabel('Frequency')
plt.show()

sellers = seller_df.sort_values(by='Completed Orders').plot(x='Seller', y='Completed Orders', kind='bar')
plt.title('Sellers by Completed orders')
plt.xlabel('Seller')
plt.show()

# %% [markdown]
# ## Investigate
#
# While most sellers provide fraudulent services or product, most are not strictly illegal. Most product are either sold accounts for different websites, or ebooks and guides for illegal activities. While selling accounts might not be allowed by the Terms of Service, it is not exactly criminal.
#
# One seller that might be looked into by the police is *topnotchdrugz*. As the name suggests, this sellers also sells drugs, next to the products we selected.
#
# Of the selected products, only one seems to be interesting for the police to investigate. That products is *order fake passports* from *caregivers420*. Though upon further investigation this sellers seems now to be offline.
#
# Unfortunately, the rest of the selected products or sellers do not seem to be of particular interest for the police to investigate. This is probably due to the chosen category, which primairily provides fraudulant digital services/products.

# %% [markdown]
# ## Legality
# The amount of legal advertisements were also included in our search on the grey market.

# %%
legal_amount = df["Legal"].value_counts()
legal_amount.plot.pie(autopct='%1.1f%%')
plt.title('Amount of Legal advertisements')
plt.ylabel('')
plt.show()

# %% [markdown]
# As seen in the above pie chart, the majority of hte 100 advertisements that were found on the chosen 'Gray Market' were categorized as not legal. This can be explained by diving deeper into the data and looking at the categories in which the items were classified, as seen in the below plot.

# %%
df.groupby(['Category', 'Legal']).size().unstack().transpose().plot(kind='pie', subplots=True, figsize=(16,8), layout=(2,3), legend=False, labels=['No', 'Yes?', 'Yes'])
plt.show()

# %%
group = df.groupby(['Seller', 'Legal']).size().unstack()
group = group.fillna(0)
group = group[group.transpose().sum() > 1]
group = group.sort_values(by = ['No', 'Yes?', 'Yes'], ascending=False)
group.transpose().plot.pie(autopct='%.1f%%', subplots=True, figsize=(15,10), layout=(3,4), legend=False, labels=['No', 'Yes?', 'Yes'])
plt.suptitle('Legal Percentage per Seller')
plt.show()

# %% [markdown]
# In the image above

# %%
group = df.groupby(['Seller'])
group = group["In Stock"].sum()
group.plot.barh()
plt.title('Sellers by Stock')
plt.xlabel('In Stock')
plt.ylabel('Seller')
plt.show()

# %% [markdown]
# # Conclusion and Reflection
# BlaBla
